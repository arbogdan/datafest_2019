# %%
# import required packages
import os
import pandas as pd

# %%
# Read in Data

weather_full = pd.read_csv('../data/weather_description.csv')  #(45253, 37)
temp_full = pd.read_csv('../data/temperature.csv') # (45253, 37)
city_full = pd.read_csv('../data/city_attributes.csv') #(36, 4)

weather_wide = weather_full.set_index('datetime').rename_axis(None).transpose().rename_axis('City').reset_index()
temp_wide = temp_full.set_index('datetime').rename_axis(None).transpose().rename_axis('City').reset_index()

# %%
weather_full.head(2)
# Out:
#               datetime Vancouver          Portland San Francisco  \
# 0  2012-10-01 12:00:00       NaN               NaN           NaN
# 1  2012-10-01 13:00:00      mist  scattered clouds    light rain
#
#         Seattle Los Angeles     San Diego     Las Vegas       Phoenix  \
# 0           NaN         NaN           NaN           NaN           NaN
# 1  sky is clear        mist  sky is clear  sky is clear  sky is clear
#
#     Albuquerque      ...        Philadelphia    New York         Montreal  \
# 0           NaN      ...                 NaN         NaN              NaN
# 1  sky is clear      ...       broken clouds  few clouds  overcast clouds
#
#          Boston     Beersheba Tel Aviv District Eilat         Haifa  \
# 0           NaN           NaN               NaN  haze           NaN
# 1  sky is clear  sky is clear      sky is clear  haze  sky is clear
#
#       Nahariyya     Jerusalem
# 0           NaN           NaN
# 1  sky is clear  sky is clear
#
# [2 rows x 37 columns]

# %% [markdown]
# ### Exercise 1

# %%
# weather_long = 
pd.melt(weather_full, id_vars = ['Country', 'City']) # var_name='Lat/Long', value_name='value'
# Out:
#               datetime Vancouver          Portland San Francisco  \
# 0  2012-10-01 12:00:00       NaN               NaN           NaN
# 1  2012-10-01 13:00:00      mist  scattered clouds    light rain
#
#         Seattle Los Angeles     San Diego     Las Vegas       Phoenix  \
# 0           NaN         NaN           NaN           NaN           NaN
# 1  sky is clear        mist  sky is clear  sky is clear  sky is clear
#
#     Albuquerque      ...        Philadelphia    New York         Montreal  \
# 0           NaN      ...                 NaN         NaN              NaN
# 1  sky is clear      ...       broken clouds  few clouds  overcast clouds
#
#          Boston     Beersheba Tel Aviv District Eilat         Haifa  \
# 0           NaN           NaN               NaN  haze           NaN
# 1  sky is clear  sky is clear      sky is clear  haze  sky is clear
#
#       Nahariyya     Jerusalem
# 0           NaN           NaN
# 1  sky is clear  sky is clear
#
# [2 rows x 37 columns]

# %%
temp_full.head(2)
# Out:
#               datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1  2012-10-01 13:00:00     284.63    282.08         289.48    281.8
#
#    Los Angeles  San Diego  Las Vegas  Phoenix  Albuquerque    ...      \
# 0          NaN        NaN        NaN      NaN          NaN    ...
# 1       291.87     291.53     293.41    296.6       285.12    ...
#
#    Philadelphia  New York  Montreal  Boston  Beersheba  Tel Aviv District  \
# 0           NaN       NaN       NaN     NaN        NaN                NaN
# 1        285.63    288.22    285.83  287.17     307.59             305.47
#
#     Eilat  Haifa  Nahariyya  Jerusalem
# 0  309.10    NaN        NaN        NaN
# 1  310.58  304.4      304.4      303.5
#
# [2 rows x 37 columns]

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# ### Exercise 3
