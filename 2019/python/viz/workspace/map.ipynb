# %% [markdown]
# # Data Viz with Python : Map

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import mplleaflet

# %% [markdown]
# ## Load and Process Data

# %% [markdown]
# ### Load City Attributes Data

# %%
df_cities = pd.read_csv("../../../data/city_attributes.csv")
print(df_cities.shape)
df_cities.head()
# Out:
# (36, 4)
#             City        Country   Latitude   Longitude
# 0      Vancouver         Canada  49.249660 -123.119339
# 1       Portland  United States  45.523449 -122.676208
# 2  San Francisco  United States  37.774929 -122.419418
# 3        Seattle  United States  47.606209 -122.332069
# 4    Los Angeles  United States  34.052231 -118.243683

# %% [markdown]
# ## Load Temperature Data

# %%
df_temperature = pd.read_csv("../../../data/temperature.csv")
print(df_temperature.shape)
df_temperature.head()
# Out:
# (45253, 37)
#               datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0  2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1  2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2  2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3  2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4  2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque    ...      \
# 0          NaN         NaN         NaN         NaN          NaN    ...
# 1   291.870000  291.530000  293.410000  296.600000   285.120000    ...
# 2   291.868186  291.533501  293.403141  296.608509   285.154558    ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952    ...
# 4   291.857503  291.553209  293.381213  296.654466   285.313345    ...
#
#    Philadelphia    New York    Montreal      Boston   Beersheba  \
# 0           NaN         NaN         NaN         NaN         NaN
# 1    285.630000  288.220000  285.830000  287.170000  307.590000
# 2    285.663208  288.247676  285.834650  287.186092  307.590000
# 3    285.756824  288.326940  285.847790  287.231672  307.391513
# 4    285.850440  288.406203  285.860929  287.277251  307.145200
#
#    Tel Aviv District       Eilat  Haifa  Nahariyya  Jerusalem
# 0                NaN  309.100000    NaN        NaN        NaN
# 1         305.470000  310.580000  304.4      304.4      303.5
# 2         304.310000  310.495769  304.4      304.4      303.5
# 3         304.281841  310.411538  304.4      304.4      303.5
# 4         304.238015  310.327308  304.4      304.4      303.5
#
# [5 rows x 37 columns]

# %% [markdown]
# **Parse str datetime into new year, year_month and date columns**

# %%
df_temperature['year'] = df_temperature.datetime.str[0:4]
df_temperature['year_month'] = df_temperature.datetime.str[0:7]
df_temperature['date'] = df_temperature.datetime.str[0:10]

# %%
print(df_temperature.shape)
df_temperature.head()
# Out:
# (45253, 40)
#               datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0  2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1  2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2  2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3  2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4  2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque     ...      \
# 0          NaN         NaN         NaN         NaN          NaN     ...
# 1   291.870000  291.530000  293.410000  296.600000   285.120000     ...
# 2   291.868186  291.533501  293.403141  296.608509   285.154558     ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952     ...
# 4   291.857503  291.553209  293.381213  296.654466   285.313345     ...
#
#        Boston   Beersheba  Tel Aviv District       Eilat  Haifa  Nahariyya  \
# 0         NaN         NaN                NaN  309.100000    NaN        NaN
# 1  287.170000  307.590000         305.470000  310.580000  304.4      304.4
# 2  287.186092  307.590000         304.310000  310.495769  304.4      304.4
# 3  287.231672  307.391513         304.281841  310.411538  304.4      304.4
# 4  287.277251  307.145200         304.238015  310.327308  304.4      304.4
#
#    Jerusalem  year  year_month        date
# 0        NaN  2012     2012-10  2012-10-01
# 1      303.5  2012     2012-10  2012-10-01
# 2      303.5  2012     2012-10  2012-10-01
# 3      303.5  2012     2012-10  2012-10-01
# 4      303.5  2012     2012-10  2012-10-01
#
# [5 rows x 40 columns]

# %% [markdown]
# **Melt temperature dataframe into long frame, rename columns and convert temperature values**

# %%
df_temperature_long = df_temperature.melt(id_vars=['datetime', 'year', 'year_month', 'date'])
df_temperature_long.rename(columns={"variable": "City", "value": "temperature"}, inplace=True)
df_temperature_long.temperature = pd.to_numeric(df_temperature_long.temperature)

# %%
print(df_temperature_long.shape)
df_temperature_long.head()
# Out:
# (1629108, 6)
#               datetime  year year_month        date       City  temperature
# 0  2012-10-01 12:00:00  2012    2012-10  2012-10-01  Vancouver          NaN
# 1  2012-10-01 13:00:00  2012    2012-10  2012-10-01  Vancouver   284.630000
# 2  2012-10-01 14:00:00  2012    2012-10  2012-10-01  Vancouver   284.629041
# 3  2012-10-01 15:00:00  2012    2012-10  2012-10-01  Vancouver   284.626998
# 4  2012-10-01 16:00:00  2012    2012-10  2012-10-01  Vancouver   284.624955

# %% [markdown]
# ### Merge City and Temperature Data

# %%
df_city_temp = df_cities.merge(df_temperature_long, on='City')

# %%
print(df_city_temp.shape)
df_city_temp.head()
# Out:
# (1629108, 9)
#         City Country  Latitude   Longitude             datetime  year  \
# 0  Vancouver  Canada  49.24966 -123.119339  2012-10-01 12:00:00  2012
# 1  Vancouver  Canada  49.24966 -123.119339  2012-10-01 13:00:00  2012
# 2  Vancouver  Canada  49.24966 -123.119339  2012-10-01 14:00:00  2012
# 3  Vancouver  Canada  49.24966 -123.119339  2012-10-01 15:00:00  2012
# 4  Vancouver  Canada  49.24966 -123.119339  2012-10-01 16:00:00  2012
#
#   year_month        date  temperature
# 0    2012-10  2012-10-01          NaN
# 1    2012-10  2012-10-01   284.630000
# 2    2012-10  2012-10-01   284.629041
# 3    2012-10  2012-10-01   284.626998
# 4    2012-10  2012-10-01   284.624955

# %% [markdown]
# ### Aggregate

# %% [markdown]
# **Aggregate merged dataframes by year, City, Latitude and Longitude**

# %%
df_city_temp_agg = df_city_temp.groupby(['year', 'City', 'Latitude', 'Longitude']).temperature.agg(
    ['min', 'max', 'mean', 'median'])
print(df_city_temp_agg.shape)
df_city_temp_agg.head()
# Out:
# (216, 4)
#                                              min     max        mean  median
# year City        Latitude  Longitude
# 2012 Albuquerque 35.084492 -106.651138  260.6300  301.41  280.718570  280.43
#      Atlanta     33.749001 -84.387978   270.8000  300.32  285.128840  285.01
#      Beersheba   31.251810  34.791302   280.7985  314.82  294.620317  293.87
#      Boston      42.358429 -71.059769   265.9600  297.94  279.923405  279.35
#      Charlotte   35.227089 -80.843132   269.3300  300.71  284.383414  283.85

# %%
df_city_temp_agg.rename(columns={"min": "min_temperature", "max": "max_temperature", "median": "median_temperature", "mean": "mean_temperature"}, inplace=True)
df_city_temp_agg.reset_index(inplace=True)

# %%
print(df_city_temp_agg.shape)
df_city_temp_agg.head()
# Out:
# (216, 8)
#    year         City   Latitude   Longitude  min_temperature  max_temperature  \
# 0  2012  Albuquerque  35.084492 -106.651138         260.6300           301.41
# 1  2012      Atlanta  33.749001  -84.387978         270.8000           300.32
# 2  2012    Beersheba  31.251810   34.791302         280.7985           314.82
# 3  2012       Boston  42.358429  -71.059769         265.9600           297.94
# 4  2012    Charlotte  35.227089  -80.843132         269.3300           300.71
#
#    mean_temperature  median_temperature
# 0        280.718570              280.43
# 1        285.128840              285.01
# 2        294.620317              293.87
# 3        279.923405              279.35
# 4        284.383414              283.85

# %% [markdown]
# **Map temperature to a size**

# %%
def make_interp_generator(domain, range):
    return lambda v: np.interp(v,domain, range)

# %%
domain = [df_city_temp_agg.mean_temperature.min(), df_city_temp_agg.mean_temperature.max()]
range = [1, 500]
interpreter = make_interp_generator(domain, range)
df_city_temp_agg['temp_size'] = df_city_temp_agg.mean_temperature.apply(interpreter)

# %% [markdown]
# ## Visualize City Temperature Map

# %%
cities = df_city_temp_agg.City.unique()
cities
# Out:
# array(['Albuquerque', 'Atlanta', 'Beersheba', 'Boston', 'Charlotte',
#        'Chicago', 'Dallas', 'Denver', 'Detroit', 'Eilat', 'Haifa',
#        'Houston', 'Indianapolis', 'Jacksonville', 'Jerusalem',
#        'Kansas City', 'Las Vegas', 'Los Angeles', 'Miami', 'Minneapolis',
#        'Montreal', 'Nahariyya', 'Nashville', 'New York', 'Philadelphia',
#        'Phoenix', 'Pittsburgh', 'Portland', 'Saint Louis', 'San Antonio',
#        'San Diego', 'San Francisco', 'Seattle', 'Tel Aviv District',
#        'Toronto', 'Vancouver'], dtype=object)

# %%
def plot_map(year):

# %%
b_is_year = df_city_temp_agg.year == '2012'
df = df_city_temp_agg[b_is_year]

plt.figure(figsize=(10,10))

color = 'blue'
for city in cities:
    b_is_city = df.City == city
    df_city = df[b_is_city]
    plt.scatter(df_city.Longitude, df_city.Latitude, c=color, s=df_city.temp_size, alpha=0.6)
mplleaflet.display()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="600"></iframe>

# %%
b_is_year = df_city_temp_agg.year == '2017'
df = df_city_temp_agg[b_is_year]

plt.figure(figsize=(10,10))

color = 'blue'
for city in cities:
    b_is_city = df.City == city
    df_city = df[b_is_city]
    plt.scatter(df_city.Longitude, df_city.Latitude, c=color, s=df_city.temp_size, alpha=0.6)
mplleaflet.display()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="600"></iframe>
